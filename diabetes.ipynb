# %% [markdown]
# Source: https://www.kaggle.com/kumargh/pimaindiansdiabetescsv
# Credit: https://machinelearningmastery.com/visualize-machine-learning-data-python-pandas/

# %%
# Univariate Histograms
import matplotlib.pyplot as plt
import pandas
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = pandas.read_csv("pima-indians-diabetes.data.csv", names=names)
data.hist(figsize=(10,10))
plt.show()

# %%
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False, figsize=(10,10))
plt.show()

# %%
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(10, 10))
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, figsize=(15,15))
plt.show()
